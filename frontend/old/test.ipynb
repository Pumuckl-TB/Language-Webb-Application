# %%
import pandas as pd
import requests

url ='http://localhost:5000/students'
response = requests.get(url = url)

# %%
response.json()
# Out:
# {'name': {'0': 'Timon',
#   '1': 'Räto',
#   '2': 'Tatjana',
#   '3': 'Debora',
#   '4': 'Radu',
#   '5': 'Timon2'},
#  'surname': {'0': 'Bodmer',
#   '1': 'Kessler',
#   '2': 'Ferri',
#   '3': 'Costa',
#   '4': 'Tanase',
#   '5': 'Bodmer2'},
#  'email': {'0': 'timon.bodmer@uzh.ch',
#   '1': 'raeto.kessler@uzh.ch',
#   '2': 'tatjana.ferri@uzh.ch',
#   '3': 'debora.costa@uzh.ch',
#   '4': 'radu.tanase@uzh.ch',
#   '5': None},
#  'exercise_duration': {'0': 60.0,
#   '1': 20.0,
#   '2': 30.0,
#   '3': 70.0,
#   '4': 50.0,
#   '5': None},
#  'objective': {'0': 'A2',
#   '1': 'A1',
#   '2': 'A2',
#   '3': 'B1',
#   '4': 'A1',
#   '5': None},
#  'user_id': {'0': 'user_id_232844',
#   '1': 'user_id_856617',
#   '2': 'user_id_203726',
#   '3': 'user_id_693269',
#   '4': 'user_id_120726',
#   '5': 'user_id_6720512'}}

# %%
students = pd.json_normalize(response.json())
students
# Out:
#   name.0 name.1   name.2  name.3 name.4  name.5 surname.0 surname.1 surname.2  \
# 0  Timon   Räto  Tatjana  Debora   Radu  Timon2    Bodmer   Kessler     Ferri
#
#   surname.3  ... objective.2 objective.3 objective.4 objective.5  \
# 0     Costa  ...          A2          B1          A1        None
#
#         user_id.0       user_id.1       user_id.2       user_id.3  \
# 0  user_id_232844  user_id_856617  user_id_203726  user_id_693269
#
#         user_id.4        user_id.5
# 0  user_id_120726  user_id_6720512
#
# [1 rows x 36 columns]

# %%
pd.read_json(response.json())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-73-595ee6cb2b2b> in <module>
# ----> 1 pd.read_json(response.json())
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     197                 else:
#     198                     kwargs[new_arg_name] = new_arg_value
# --> 199             return func(*args, **kwargs)
#     200
#     201         return cast(F, wrapper)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# ...

# %%
pd.read_json(url)
# Out:
#       name  surname                 email  exercise_duration objective  \
# 0    Timon   Bodmer   timon.bodmer@uzh.ch               60.0        A2
# 1     Räto  Kessler  raeto.kessler@uzh.ch               20.0        A1
# 2  Tatjana    Ferri  tatjana.ferri@uzh.ch               30.0        A2
# 3   Debora    Costa   debora.costa@uzh.ch               70.0        B1
# 4     Radu   Tanase    radu.tanase@uzh.ch               50.0        A1
# 5   Timon2  Bodmer2                  None                NaN      None
#
#            user_id
# 0   user_id_232844
# 1   user_id_856617
# 2   user_id_203726
# 3   user_id_693269
# 4   user_id_120726
# 5  user_id_6720512

# %%
userid = userid.max()+1

# %%
dict = pd.read_json(url).to_dict(orient='list')

dict
# Out:
# {'name': ['Timon', 'Räto', 'Felix', 'Tatjana', 'Debora', 'Radu', 'Max'],
#  'surname': ['Bodmer',
#   'Kessler',
#   'Jost',
#   'Ferri',
#   'Costa',
#   'Tanase',
#   'Muster'],
#  'email': ['timon.bodmer@uzh.ch',
#   'raeto.kessler@uzh.ch',
#   'felix.jost@uzh.ch',
#   'tatjana.ferri@uzh.ch',
#   'debora.costa@uzh.ch',
#   'radu.tanase@uzh.ch',
#   'Max.Muster@test.com'],
#  'exercise_duration': [60, 20, 40, 30, 70, 50, 10],
#  'objective': ['A2', 'A1', 'B2', 'A2', 'B1', 'A1', 'C1'],
#  'user_id': ['user_id_0',
#   'user_id_1',
#   'user_id_2',
#   'user_id_3',
#   'user_id_4',
#   'user_id_5',
#   'user_id_10']}

# %%
import urllib.request as request
data = json_file
url = 'http://localhost:5000/students'
req = request.Request(url, data, {'Content-Type': 'application/json'})

# %%
import requests
import pandas as pd
url ='http://localhost:5000/students'
response = requests.get(url = url)

# %%
students = pd.read_json(url)

students
# Out:
#       name  surname                 email  exercise_duration objective  \
# 0     Räto  Kessler  raeto.kessler@uzh.ch                 20        A1
# 1    Felix     Jost    fel.jost@gmail.com                 20        B1
# 2    Timon   Bodmer       timon@bodmer.ch                 20        B1
# 3  Tatjana    Ferri  tatja@work-email.com                 23        C2
#
#            user_id
# 0   user_id_276357
# 1  user_id_8994800
# 2  user_id_3964535
# 3  user_id_1554007

# %%
students['fullname'] = students['name'] + ' ' +students['surname']
students
# Out:
#       name  surname                 email  exercise_duration objective  \
# 0     Räto  Kessler  raeto.kessler@uzh.ch                 20        A1
# 1    Felix     Jost    fel.jost@gmail.com                 20        B1
# 2    Timon   Bodmer       timon@bodmer.ch                 20        B1
# 3  Tatjana    Ferri  tatja@work-email.com                 23        C2
#
#            user_id       fullname
# 0   user_id_276357   Räto Kessler
# 1  user_id_8994800     Felix Jost
# 2  user_id_3964535   Timon Bodmer
# 3  user_id_1554007  Tatjana Ferri

# %%
value = 'Räto Kessler'

# %%
name = value.split(' ')[0]
surname = value.split(' ')[1]

# %%
json_file
# Out:
# "{'name': 'Räto', 'surname': 'Kessler'}"

# %%
#FRONTEND
import requests
import pandas as pd

json_file = {'name': "Räto",'surname': "Kessler"}
response = requests.post('http://localhost:5000/getexerciseml', json=json_file)
print(response.json())
# Out:
# {'name': {'1': 'Räto', '2': 'Räto', '3': 'Räto', '4': 'Räto'}, 'surname': {'1': 'Kessler', '2': 'Kessler', '3': 'Kessler', '4': 'Kessler'}, 'user_id': {'1': 'user_id_276357', '2': 'user_id_276357', '3': 'user_id_276357', '4': 'user_id_276357'}, 'block_name': {'1': 'Die Firma', '2': 'Die Firma', '3': 'Die Firma', '4': 'Die Firma'}, 'block_id': {'1': 3, '2': 3, '3': 3, '4': 3}, 'task_id': {'1': 'task_id_13', '2': 'task_id_14', '3': 'task_id_15', '4': 'task_id_16'}, 'text': {'1': 'Die Projektleiterin startet ein Projekt.', '2': '[Sie] startet ein Projekt.', '3': '[Sie] startet', '4': '[es].'}}

# %%
pd.read_json(response)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-22a1b0a9c96d> in <module>
# ----> 1 pd.read_json(response)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     197                 else:
#     198                     kwargs[new_arg_name] = new_arg_value
# --> 199             return func(*args, **kwargs)
#     200
#     201         return cast(F, wrapper)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# ...

# %%
#FRONTEND
import requests
import pandas as pd


json_file = {'name': name,'surname': surname}
response = requests.post('http://localhost:5000/getexerciseml', json=json_file)
print(response.json())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-4098f2bcbfd5> in <module>
#       4
#       5
# ----> 6 json_file = {'name': name,'surname': surname}
#       7 response = requests.post('http://localhost:5000/getexerciseml', json=json_file)
#       8 print(response.json())
#
# NameError: name 'name' is not defined

# %%
import urllib.request as request
data = '{"name":{"0":"Timon"},"surname":{"0":"Bodmer"},"email":{"0":"timon.bodmer@uzh.ch"},"exercise_duration":{"0":60},"objective":{"0":"A2"},"user_id":{"0":"user_id_0"}}'
url = 'http://localhost:5000/students/print'
req = request.Request(url, data, {'Content-Type': 'application/json'})

# %%
import requests
response = requests.post('http://localhost:5000/students/print', json=json_file)
print(response.json())
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-41-0dcf36225b01> in <module>
#       1 import requests
#       2 response = requests.post('http://localhost:5000/students/print', json=json_file)
# ----> 3 print(response.json())
#
# ~\anaconda3\lib\site-packages\requests\models.py in json(self, **kwargs)
#     896                     # used.
#     897                     pass
# --> 898         return complexjson.loads(self.text, **kwargs)
#     899
#     900     @property
#
# ~\anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
# ...

# %%
json_file = '{"name":{"0":"Timon"},"surname":{"0":"Bodmer"},"email":{"0":"timon.bodmer@uzh.ch"},"exercise_duration":{"0":60},"objective":{"0":"A2"}}'

# %%
json_file
# Out:
# '{"name":{"0":"Timon"},"surname":{"0":"Bodmer"},"email":{"0":"timon.bodmer@uzh.ch"},"exercise_duration":{"0":60},"objective":{"0":"A2"}}'

# %%
import requests
import pandas as pd
import requests

json_file = '{"name":{"0":"Timon0"},"surname":{"0":"Bodmer4"},"email":{"0":"timon2.bodmer@uzh.ch"},"exercise_duration":{"0":602},"objective":{"0":"A3"}}'
response = requests.post('http://localhost:5000/addstudent', json=json_file)
print(response.text)
# Out:
# {
#   "message": "student added"
# }

# %%
dict = {'name': ['Firstname...'], 'surname': ['Lastname...'], 'email': ['Email...'], 'exercise_duration': ['Exercise Duration...'], 'objective': ['Objective...']}

# %%
pd.DataFrame.from_dict(dict).to_json()
# Out:
# '{"name":{"0":"Firstname..."},"surname":{"0":"Lastname..."},"email":{"0":"Email..."},"exercise_duration":{"0":"Exercise Duration..."},"objective":{"0":"Objective..."}}'

# %%
import requests
import pandas as pd
import requests

json_file = '{"name":"Timon0","surname":"Bodmer4","email":"timon2.bodmer@uzh.ch","exercise_duration":602,"objective":A3"}'
response = requests.post('http://localhost:5000/addstudent', json=json_file)
print(response.text)
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN"
#   "http://www.w3.org/TR/html4/loose.dtd">
# <html>
#   <head>
#     <title>ValueError: Expected object or value // Werkzeug Debugger</title>
#     <link rel="stylesheet" href="?__debugger__=yes&amp;cmd=resource&amp;f=style.css"
#         type="text/css">
#     <!-- We need to make sure this has a favicon so that the debugger does
#          not by accident trigger a request to /favicon.ico which might
#          change the application state. -->
#     <link rel="shortcut icon"
#         href="?__debugger__=yes&amp;cmd=resource&amp;f=console.png">
#     <script src="?__debugger__=yes&amp;cmd=resource&amp;f=jquery.js"></script>
#     <script src="?__debugger__=yes&amp;cmd=resource&amp;f=debugger.js"></script>
#     <script type="text/javascript">
#       var TRACEBACK = 2691334417808,
#           CONSOLE_MODE = false,
#           EVALEX = true,
#           EVALEX_TRUSTED = false,
# ...

# %%
#FRONTEND
import requests
import pandas as pd

json_file = {'name': 'Felix', 'surname': 'Jost'}
response = requests.post('http://localhost:5000/deletestudent', json=json_file)
print(response.text)
# Out:
# {
#   "message": "student deleted"
# }

# %%
#FRONTEND
import requests
import pandas as pd

json_file = {'name': "Felix",'surname': "Jost"}
response = requests.post('http://localhost:5000/getexerciseml', json=json_file)
print(response.json())
# Out:
# {'name': {}, 'surname': {}, 'user_id': {}, 'block_name': {}, 'block_id': {}, 'task_id': {}, 'text': {}}

# %%
dict = response.json()

# %%
pd.DataFrame.from_dict(response.json()).to_dict(orient='list')
# Out:
# {'name': ['Räto', 'Räto', 'Räto', 'Räto'],
#  'surname': ['Kessler', 'Kessler', 'Kessler', 'Kessler'],
#  'user_id': ['user_id_276357',
#   'user_id_276357',
#   'user_id_276357',
#   'user_id_276357'],
#  'block_name': ['Die Firma', 'Die Firma', 'Die Firma', 'Die Firma'],
#  'block_id': [3, 3, 3, 3],
#  'task_id': ['task_id_13', 'task_id_14', 'task_id_15', 'task_id_16'],
#  'text': ['Die Projektleiterin startet ein Projekt.',
#   '[Sie] startet ein Projekt.',
#   '[Sie] startet',
#   '[es].']}

# %%
from flask import Flask, request, jsonify
import pandas as pd
import psycopg2
from psycopg2 import OperationalError
from sqlalchemy import create_engine
import json
import numpy as np


app = Flask(__name__)



# Create Connection to the SQL Database
def create_connection(db_name, db_user, db_password, db_host, db_port):
    connection = None
    try:
        connection = psycopg2.connect(
            database=db_name,
            user=db_user,
            password=db_password,
            host=db_host,
            port=db_port,
        )
        print("Connection to PostgreSQL DB successful")
    except OperationalError as e:
        print(f"The error '{e}' occurred")
    return connection

create_connection(db_name='group1',
                 db_user='admin_group1',
                 db_password="pXysH3Qdhz7ZLhkRgz89mTQCQG",
                 db_host='35.228.244.65',
                 db_port='5432')


engine = create_engine('postgresql://admin_group1:pXysH3Qdhz7ZLhkRgz89mTQCQG@35.228.244.65:5432/group1')
# Out:
# Connection to PostgreSQL DB successful

# %%
pd.read_sql('rec_task_ML', engine)
# Out:
#        name  surname         user_id        block_name  block_id     task_id  \
# 0     Timon   Bodmer  user_id_245312  Alles Ã¼ber Raum        14  task_id_50
# 1      Räto  Kessler  user_id_276357         Die Firma         3  task_id_13
# 2      Räto  Kessler  user_id_276357         Die Firma         3  task_id_14
# 3      Räto  Kessler  user_id_276357         Die Firma         3  task_id_15
# 4      Räto  Kessler  user_id_276357         Die Firma         3  task_id_16
# 5     Felix     Jost  user_id_216367         Die Firma         4  task_id_17
# 6     Felix     Jost  user_id_216367         Die Firma         4  task_id_18
# 7     Felix     Jost  user_id_216367         Die Firma         4  task_id_19
# 8     Felix     Jost  user_id_216367         Die Firma         4  task_id_20
# 9     Felix     Jost  user_id_216367         Die Firma         4  task_id_21
# 10    Felix     Jost  user_id_216367         Die Firma         4  task_id_22
# ...

# %%
pd.read_sql('users2', engine)
# Out:
#       name  surname                 email  exercise_duration objective  \
# 0     Räto  Kessler  raeto.kessler@uzh.ch               20.0        A1
# 1    Felix     Jost    fel.jost@gmail.com               20.0        B1
# 2    Timon   Bodmer       timon@bodmer.ch               20.0        B1
# 3  Tatjana    Ferri  tatja@work-email.com               23.0        C2
#
#            user_id
# 0   user_id_276357
# 1  user_id_8994800
# 2  user_id_3964535
# 3  user_id_1554007

# %%
#FRONTEND
import requests
import pandas as pd
json_file = {'name': "Räto", 'surname': "Kessler", 'item_id': 130}
response = requests.post('http://localhost:5000/assignhot', json=json_file)
print(response.text)
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN"
#   "http://www.w3.org/TR/html4/loose.dtd">
# <html>
#   <head>
#     <title>KeyError: 0 // Werkzeug Debugger</title>
#     <link rel="stylesheet" href="?__debugger__=yes&amp;cmd=resource&amp;f=style.css"
#         type="text/css">
#     <!-- We need to make sure this has a favicon so that the debugger does
#          not by accident trigger a request to /favicon.ico which might
#          change the application state. -->
#     <link rel="shortcut icon"
#         href="?__debugger__=yes&amp;cmd=resource&amp;f=console.png">
#     <script src="?__debugger__=yes&amp;cmd=resource&amp;f=jquery.js"></script>
#     <script src="?__debugger__=yes&amp;cmd=resource&amp;f=debugger.js"></script>
#     <script type="text/javascript">
#       var TRACEBACK = 1642420602480,
#           CONSOLE_MODE = false,
#           EVALEX = true,
#           EVALEX_TRUSTED = false,
#           SECRET = "FJ72pWOybmdt5sPEI2h4";
#     </script>
# ...

# %%
import psycopg2
from psycopg2 import OperationalError
from sqlalchemy import create_engine

def create_connection(db_name, db_user, db_password, db_host, db_port):
    connection = None
    try:
        connection = psycopg2.connect(
            database=db_name,
            user=db_user,
            password=db_password,
            host=db_host,
            port=db_port,
        )
        print("Connection to PostgreSQL DB successful")
    except OperationalError as e:
        print(f"The error '{e}' occurred")
    return connection

create_connection(db_name='group1',
                 db_user='admin_group1',
                 db_password="pXysH3Qdhz7ZLhkRgz89mTQCQG",
                 db_host='35.228.244.65',
                 db_port='5432')


engine = create_engine('postgresql://admin_group1:pXysH3Qdhz7ZLhkRgz89mTQCQG@35.228.244.65:5432/group1')

# pd.read_sql('hot_topics_all', engine)

pd.read_sql('progress_items2', engine)
# Out:
# Connection to PostgreSQL DB successful
#           field            area_name  area_order              section_name  \
# 0    vocabulary     General Concepts        10.0                      Time
# 1    vocabulary     General Concepts        10.0              Day and Week
# 2    vocabulary     General Concepts        10.0            Month and Year
# 3    vocabulary     General Concepts        10.0                     Space
# 4    vocabulary     General Concepts        10.0                   Numbers
# ..          ...                  ...         ...                       ...
# 163     grammar  Subordinate Clauses       110.0                Concessive
# 164     grammar  Subordinate Clauses       110.0                 of Manner
# 165     grammar  Subordinate Clauses       110.0                of Purpose
# 166     grammar  Subordinate Clauses       110.0             Interrogative
# 167     grammar  Subordinate Clauses       110.0  Infinitive Constructions
#
# ...

# %%
#FRONTEND
import requests
import pandas as pd
response = requests.post('http://localhost:5000/progress')
print(response.text)
# Out:
# {"field":{"0":"vocabulary","1":"vocabulary","2":"vocabulary","3":"vocabulary","4":"vocabulary","5":"vocabulary","6":"vocabulary","7":"vocabulary","8":null,"9":"vocabulary","10":"vocabulary","11":"vocabulary","12":"vocabulary","13":"vocabulary","14":"vocabulary","15":"vocabulary","16":"vocabulary","17":"vocabulary","18":"vocabulary","19":"vocabulary","20":"vocabulary","21":"vocabulary","22":"vocabulary","23":"vocabulary","24":"vocabulary","25":"vocabulary","26":"vocabulary","27":"vocabulary","28":null,"29":"vocabulary","30":"vocabulary","31":null,"32":"vocabulary","33":"vocabulary","34":"vocabulary","35":"vocabulary","36":"vocabulary","37":"vocabulary","38":"vocabulary","39":"vocabulary","40":"vocabulary","41":"vocabulary","42":"vocabulary","43":"vocabulary","44":"vocabulary","45":"vocabulary","46":"vocabulary","47":"vocabulary","48":"vocabulary","49":"vocabulary","50":"vocabulary","51":"vocabulary","52":"vocabulary","53":"vocabulary","54":"vocabulary","55":"vocabulary","56":"vocabula
# ...

# %%
json_file = {'name': "Timon",'surname': "Bodmer"}
response = requests.post('http://localhost:5000/ml', json=json_file)
print(response.text)
# Out:
# {"word_instance":{"0":1,"1":1,"2":1,"3":1,"4":1,"5":1,"42":1,"62":1},"word_type":{"0":"article","1":"article","2":"article","3":"article","4":"article","5":"article","42":"preposition","62":"verb"},"basic_form":{"0":"der","1":"der","2":"der","3":"ein","4":"der","5":"der","42":"ab","62":"warten"},"text_x":{"0":"Der Mann beschreibt [den] Wanderern den Weg.","1":"[Die] Wanderer danken dem Mann.","2":"[Der] Mann gr\u00c3\u00bc\u00c3\u0178t sie.","3":"[Eine] Touristin macht ein Foto mit dem Mann.","4":"[Der] Rucksack","5":"[der] Touristin ist leicht.","42":"Der Vertrag gilt [ab] 2021.","62":"Der Patient [wartet] heute eine Stunde."},"task_level":{"0":"A1","1":"A1","2":"A1","3":"A1","4":"A1","5":"A1","42":"A1","62":"A2"},"item_id":{"0":82,"1":82,"2":82,"3":82,"4":82,"5":82,"42":108,"62":123},"block_id":{"0":1,"1":1,"2":1,"3":1,"4":1,"5":1,"42":1,"62":1},"block_name":{"0":"Die Wanderung","1":"Die Wanderung","2":"Die Wanderung","3":"Die Wanderung","4":"Die Wanderung","5":"Die Wanderung","42"
# ...

# %%
text = response.json()
text
# Out:
# {'word_instance': {'0': 1,
#   '1': 1,
#   '2': 1,
#   '3': 1,
#   '4': 1,
#   '5': 1,
#   '42': 1,
#   '62': 1},
#  'word_type': {'0': 'article',
#   '1': 'article',
#   '2': 'article',
#   '3': 'article',
#   '4': 'article',
#   '5': 'article',
#   '42': 'preposition',
#   '62': 'verb'},
#  'basic_form': {'0': 'der',
#   '1': 'der',
#   '2': 'der',
#   '3': 'ein',
#   '4': 'der',
#   '5': 'der',
#   '42': 'ab',
#   '62': 'warten'},
#  'text_x': {'0': 'Der Mann beschreibt [den] Wanderern den Weg.',
#   '1': '[Die] Wanderer danken dem Mann.',
#   '2': '[Der] Mann grÃ¼ÃŸt sie.',
#   '3': '[Eine] Touristin macht ein Foto mit dem Mann.',
#   '4': '[Der] Rucksack',
#   '5': '[der] Touristin ist leicht.',
#   '42': 'Der Vertrag gilt [ab] 2021.',
#   '62': 'Der Patient [wartet] heute eine Stunde.'},
#  'task_level': {'0': 'A1',
#   '1': 'A1',
#   '2': 'A1',
#   '3': 'A1',
#   '4': 'A1',
#   '5': 'A1',
#   '42': 'A1',
#   '62': 'A2'},
#  'block_id': {'0': 1,
#   '1': 1,
#   '2': 1,
# ...

# %%
pd.set_option('display.max_columns', None)
pd.DataFrame.from_dict(response.json()).head(11)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-1ec8f859a6d3> in <module>
#       1 pd.set_option('display.max_columns', None)
# ----> 2 pd.DataFrame.from_dict(response.json().decode('utf8')).head(11)
#       3 text.decode('utf8')
#
# AttributeError: 'dict' object has no attribute 'decode'

# %%
text = 'gr\u00c3\u00bc\u00c3\u0178t sie'
print(text)
# Out:
# grÃ¼ÃŸt sie

# %%
import unicode
def force_to_unicode(text):
    "If text is unicode, it is returned as is. If it's str, convert it to Unicode using UTF-8 encoding"
    return text if isinstance(text, unicode) else text.decode('utf8')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-54-b412d97e0fea> in <module>
# ----> 1 import unicode
#       2 def force_to_unicode(text):
#       3     "If text is unicode, it is returned as is. If it's str, convert it to Unicode using UTF-8 encoding"
#       4     return text if isinstance(text, unicode) else text.decode('utf8')
#
# ModuleNotFoundError: No module named 'unicode'

# %%
force_to_unicode(text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-250305be5c23> in <module>
# ----> 1 force_to_unicode(text)
#
# <ipython-input-52-3be4076c13e5> in force_to_unicode(text)
#       1 def force_to_unicode(text):
#       2     "If text is unicode, it is returned as is. If it's str, convert it to Unicode using UTF-8 encoding"
# ----> 3     return text if isinstance(text, unicode) else text.decode('utf8')
#
# NameError: name 'unicode' is not defined

# %%
pd.read_sql('answers2', engine)
# Out:
#                                                  text     name  surname  \
# 0        Der Mann beschreibt [den] Wanderern den Weg.     Räto  Kessler
# 1                     [Die] Wanderer danken dem Mann.    Timon   Bodmer
# 2                               [Der] Mann grüßt sie.    Timon   Bodmer
# 3       [Eine] Touristin macht ein Foto mit dem Mann.  Debora     Costa
# 4                                      [Der] Rucksack     Räto  Kessler
# 5                         [der] Touristin ist leicht.    Felix     Jost
# 6        Die Heimatstadt des [Portugiesen] ist Porto.    Timon   Bodmer
# 7    Thessaloniki ist die Heimatstadt des [Griechen].    Räto   Kessler
# 8        Die Heimatstadt des [Chinesen] ist Hongkong.    Timon   Bodmer
# 9                   Der [Bulgare] spricht Bulgarisch.  Debora     Costa
# 10  Eine Russin erklärt einem [Chinesen] das Problem.     Räto  Kessler
# 11                Der [Franzose] spricht Französisch.    Felix     Jost
# ...

# %%
json = '{"name":{"1":"Timon","2":"Timon","3":"Timon","4":"Timon","5":"Timon","6":"Timon","7":"Timon","8":"Timon","9":"Timon","10":"Timon","11":"Timon","12":"Timon","13":"Timon","14":"Timon","15":"Timon","16":"Timon"},"surname":{"1":"Bodmer","2":"Bodmer","3":"Bodmer","4":"Bodmer","5":"Bodmer","6":"Bodmer","7":"Bodmer","8":"Bodmer","9":"Bodmer","10":"Bodmer","11":"Bodmer","12":"Bodmer","13":"Bodmer","14":"Bodmer","15":"Bodmer","16":"Bodmer"},"task":{"1":"task_id_0","2":"task_id_1","3":"task_id_2","4":"task_id_3","5":"task_id_4","6":"task_id_5","7":"task_id_37","8":"task_id_57","9":"task_id_0","10":"task_id_1","11":"task_id_2","12":"task_id_3","13":"task_id_4","14":"task_id_5","15":"task_id_37","16":"task_id_57"},"elapsed":{"1":0.434322685,"2":0.434322685,"3":0.434322685,"4":0.434322685,"5":0.434322685,"6":0.434322685,"7":0.434322685,"8":0.434322685,"9":0.434322685,"10":0.434322685,"11":0.434322685,"12":0.434322685,"13":0.434322685,"14":0.434322685,"15":0.434322685,"16":0.434322685}}'

# %%
pd.read_json(json)
# Out:
#      name surname        task   elapsed
# 1   Timon  Bodmer   task_id_0  0.434323
# 2   Timon  Bodmer   task_id_1  0.434323
# 3   Timon  Bodmer   task_id_2  0.434323
# 4   Timon  Bodmer   task_id_3  0.434323
# 5   Timon  Bodmer   task_id_4  0.434323
# 6   Timon  Bodmer   task_id_5  0.434323
# 7   Timon  Bodmer  task_id_37  0.434323
# 8   Timon  Bodmer  task_id_57  0.434323
# 9   Timon  Bodmer   task_id_0  0.434323
# 10  Timon  Bodmer   task_id_1  0.434323
# 11  Timon  Bodmer   task_id_2  0.434323
# 12  Timon  Bodmer   task_id_3  0.434323
# 13  Timon  Bodmer   task_id_4  0.434323
# 14  Timon  Bodmer   task_id_5  0.434323
# 15  Timon  Bodmer  task_id_37  0.434323
# 16  Timon  Bodmer  task_id_57  0.434323

# %%
#FRONTEND
import requests
import pandas as pd
json_file = {'name': "Räto",'surname': "Kessler"}
response = requests.post('http://localhost:5000/getexercisehot', json=json_file)
print(response.text)
# Out:
# {"name":{"1":"R\u00e4to","2":"R\u00e4to","3":"R\u00e4to","4":"R\u00e4to"},"surname":{"1":"Kessler","2":"Kessler","3":"Kessler","4":"Kessler"},"user_id":{"1":"user_id_488781","2":"user_id_488781","3":"user_id_488781","4":"user_id_488781"},"item_id":{"1":130.0,"2":130.0,"3":130.0,"4":130.0},"block_name":{"1":"Im Krankenhaus","2":"Eltern und Kinder","3":"Eltern und Kinder","4":"Feierabend"},"block_id":{"1":2.0,"2":3.0,"3":4.0,"4":6.0},"task_id":{"1":"task_id_58","2":"task_id_59","3":"task_id_60","4":"task_id_62"},"text":{"1":"Der Patient [hat] auch gestern eine Stunde [gewartet]. ","2":"Das Kind [hat] ein Eis [gegessen].","3":"Die Eltern [haben] ihm kein Eis [gegeben].","4":"Wir [haben] gestern Abend im Restaurant [gegessen]."}}
